# %% [markdown]
# ## Iris Dataset
# Demonstrating Data Analysis process yet again for an Iris dataset

# %%
# Load the iris dataset
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the iiris dataset
data = load_iris()
# Create a DataFrame from the dataset
df = pd.DataFrame(data.data, columns=data.feature_names)    

print("First few rows of the iris dataset:")
print(df.head())
# Out:
# First few rows of the iris dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Standardize the data using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X, y = data.data, data.target
df_scaled = scaler.fit_transform(X)
print("\nAfter standardizing the data:")
print(df_scaled[:5])  # Print first 5 rows of scaled data
# Out:
# After standardizing the data:
# [[-0.90068117  1.01900435 -1.34022653 -1.3154443 ]
#  [-1.14301691 -0.13197948 -1.34022653 -1.3154443 ]
#  [-1.38535265  0.32841405 -1.39706395 -1.3154443 ]
#  [-1.50652052  0.09821729 -1.2833891  -1.3154443 ]
#  [-1.02184904  1.24920112 -1.34022653 -1.3154443 ]]

# %%
# Describe the dataset
print("\nDataset Information:")
print(df.info())            
print("\nDataset Description:")
print(df.describe())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB
# None
#
# Dataset Description:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# ...

# %%
# Add target column to df for visualization
df_with_target = df.copy()
df_with_target['target'] = y

# Visualize the data
sns.pairplot(df_with_target, hue="target", palette="viridis")
plt.suptitle('Pairplot of Iris Dataset', y=1.02)
plt.show()
