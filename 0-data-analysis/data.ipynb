# %% [markdown]
# ## Data Preprocessing:
# - Refers to transformation before fitting model

# %% [markdown]
# ## StandardScaler
#
# Standardization is a preprocessing method used to transform continuous data to make it look normally distributed.
#
# * The StandardScaler assumes your data is normally distributed (continuous numerical data) within each feature and will scale them such that the distribution is now centred around 0, with a standard deviation of 1.
#
# <img src="https://github.com/awantik/machine-learning-slides/blob/master/pp4.PNG?raw=true" alt="Mathematical formula for standardization showing xi minus mean of x divided by standard deviation of x, written in pink italic font. The formula is centered on a white background, conveying a neutral and educational tone.">
#
# When to standardize:
# * Models in linear space
# * Dataset features have high variance
# * If data is not normally distributed, this is not the best scaler to use.

# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Lets demonstrate Standardization in Preprocessing

# %%
# Generate random data
df = pd.DataFrame({
	'x1': np.random.normal(5, 2, 10000),
	'x2': np.random.normal(0, 5, 10000),
	'x3': np.random.normal(-5, 8, 10000),
	'x4': np.random.normal(10, 3, 10000),
	'x5': np.random.normal(2, 1, 10000),
})
# plot the data
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Standardize the data using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# Convert the scaled data back to a DataFrame
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)

# Plot the standardized data
df_scaled.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Preprocessing:
# There are several other Preprocessing Techinques to Prepare data for modelling
# * This is beyond this repo - I will update as I learn more...

# %% [markdown]
# ## 3. MinMaxScaler
# * One of the most popular
# * Calculate - Subtract min of column & div by difference between max & min
#
#
#
#
# <img src="https://github.com/awantik/machine-learning-slides/blob/master/pp3.PNG?raw=true">
#
#
#
# * Data shifts between 0 & 1
# * If distribution not suitable for StandardScaler, this scaler works out.
# * Sensitive to outliers

# %%
df = pd.DataFrame({
    # positive skew
    'x1': np.random.chisquare(8, 1000),
    # negative skew 
    'x2': np.random.beta(8, 2, 1000) * 40,
    # no skew
    'x3': np.random.normal(50, 3, 1000)
})
df.plot.kde()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.DataFrame({
#       2     # positive skew
#       3     'x1': np.random.chisquare(8, 1000),
#       4     # negative skew
#       5     'x2': np.random.beta(8, 2, 1000) * 40,
#       6     # no skew
#       7     'x3': np.random.normal(50, 3, 1000)
#       8 })
#       9 df.plot.kde()
#
# NameError: name 'pd' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
data_tf = mm.fit_transform(df)
df = pd.DataFrame(data_tf,columns=['x1','x2','x3'])
df.plot.kde()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 mm = MinMaxScaler()
# ----> 3 data_tf = mm.fit_transform(df)
#       4 df = pd.DataFrame(data_tf,columns=['x1','x2','x3'])
#       5 df.plot.kde()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## All Data is the Same
# * How we handle datasets, changes depending on type and model specification, However, through Research and this Repo - I wanted to demonstrate how I this has Resonanted with me!
